# %% [markdown]
# Run the `visualize_experiments.ipynb` notebook for every experiment in the results folder.
#
# Based on https://stackoverflow.com/questions/58880620/running-a-jupyter-notebook-from-another-notebook-with-parameters

# %%
RESULTS_ROOT = '/media/mcndt/thesis/thesis-cyborg-plants/results/'

experiments = [
  # 'gdc_can1_grapevine',
  # 'gdc_can2_grapevine',
  # 'gdc_can3_grapevine',

  # 'gdc_can1_grapevine_no_deficit',
  # 'gdc_can2_grapevine_no_deficit',
  # 'gdc_can3_grapevine_no_deficit',

  # 'gdc_can1_grapevine_10_days_no_deficit',
  # 'gdc_can2_grapevine_10_days_no_deficit',
  # 'gdc_can3_grapevine_10_days_no_deficit',

  'gdc_can1_6days_0',
  'gdc_can1_6days_1',
  'gdc_can1_6days_2'
]

# %%
import platform

for exp in experiments:
  EXPERIMENT = exp
  print('+' * 64)
  print(f'EXPERIMENT:    {EXPERIMENT}')
  print('+' * 64)
  print('\n\n\n')
  if platform.system() == 'Windows':
    # %run ".\\visualize_experiment_data.ipynb"
    # %run ".\\rc_experiments.ipynb"
  else:
    # %run './visualize_experiment_data.ipynb'
    # %run "./rc_experiments.ipynb"
# Out:
# ++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# EXPERIMENT:    gdc_can1_6days_0
# ++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
#
#
#
#
# Time steps: 144
# Time range: 2012-08-01 00:00:00 to 2012-08-06 23:00:00
# Available state variables: ['An', 'Ci', 'E', 'Eabs', 'Ei', 'Flux', 'FluxC', 'Tlc', 'gb', 'gs', 'par_photo.dHd', 'psi_head', 'u']
# State size: 360
# States shape: (144, 100, 8, 11) = (time_step, n_samplings, leaf, state_variable)
# Target shape: (144, 4) = (time_step, target_variable)
# errors_mean shape: (4, 11)  min: 0.3949   max: 1.0000
#  errors_std shape: (4, 11)  min: 0.0000   max: 0.0448
# States shape: (144, 100, 8, 11) = (time_step, n_samplings, leaf, state_variable)
# Target shape: (144, 4) = (time_step, target_variable)
# errors_mean shape: (4, 11)  min: 0.4012   max: 1.0000
#  errors_std shape: (4, 11)  min: 0.0000   max: 0.0443
# errors_mean shape: (7, 11)  min: 0.3120   max: 1.0000
#  errors_std shape: (7, 11)  min: 0.0000   max: 0.1484
# errors_mean shape: (11, 11) min: 0.3551   max: 1.0000
#  errors_std shape: (11, 11) min: 0.0000   max: 0.0224
# errors_mean shape: (9, 11)  min: 0.3714   max: 1.0000
#  errors_std shape: (9, 11)  min: 0.0000   max: 0.0302
# States shape: (144, 1, 16, 11) = (time_step, leaf, state_variable)
# Target shape: (144,) = (time_step, target_variable)
# (11, 144)
# ++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# EXPERIMENT:    gdc_can1_6days_1
# ++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
#
#
#
#
# Time steps: 144
# Time range: 2012-08-02 00:00:00 to 2012-08-07 23:00:00
# Available state variables: ['An', 'Ci', 'E', 'Eabs', 'Ei', 'Flux', 'FluxC', 'Tlc', 'gb', 'gs', 'par_photo.dHd', 'psi_head', 'u']
# State size: 360
# States shape: (144, 100, 8, 11) = (time_step, n_samplings, leaf, state_variable)
# Target shape: (144, 4) = (time_step, target_variable)
# errors_mean shape: (4, 11)  min: 0.2831   max: 1.0000
#  errors_std shape: (4, 11)  min: 0.0000   max: 0.0425
# States shape: (144, 100, 8, 11) = (time_step, n_samplings, leaf, state_variable)
# Target shape: (144, 4) = (time_step, target_variable)
# errors_mean shape: (4, 11)  min: 0.2969   max: 1.0000
#  errors_std shape: (4, 11)  min: 0.0000   max: 0.0444
# errors_mean shape: (7, 11)  min: 0.3570   max: 1.0000
#  errors_std shape: (7, 11)  min: 0.0000   max: 0.1340
# errors_mean shape: (11, 11) min: 0.3919   max: 1.0000
#  errors_std shape: (11, 11) min: 0.0000   max: 0.0163
# errors_mean shape: (9, 11)  min: 0.3315   max: 1.0000
#  errors_std shape: (9, 11)  min: 0.0000   max: 0.0317
# States shape: (144, 1, 16, 11) = (time_step, leaf, state_variable)
# Target shape: (144,) = (time_step, target_variable)
# (11, 144)
# ++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# EXPERIMENT:    gdc_can1_6days_2
# ++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
#
#
#
#
# Time steps: 144
# Time range: 2012-08-03 00:00:00 to 2012-08-08 23:00:00
# Available state variables: ['An', 'Ci', 'E', 'Eabs', 'Ei', 'Flux', 'FluxC', 'Tlc', 'gb', 'gs', 'par_photo.dHd', 'psi_head', 'u']
# State size: 360
# States shape: (144, 100, 8, 11) = (time_step, n_samplings, leaf, state_variable)
# Target shape: (144, 4) = (time_step, target_variable)
# errors_mean shape: (4, 11)  min: 0.2721   max: 1.0000
#  errors_std shape: (4, 11)  min: 0.0000   max: 0.0426
# States shape: (144, 100, 8, 11) = (time_step, n_samplings, leaf, state_variable)
# Target shape: (144, 4) = (time_step, target_variable)
# errors_mean shape: (4, 11)  min: 0.2805   max: 1.0000
#  errors_std shape: (4, 11)  min: 0.0000   max: 0.0446
# errors_mean shape: (7, 11)  min: 0.3594   max: 1.0000
#  errors_std shape: (7, 11)  min: 0.0000   max: 0.1357
# errors_mean shape: (11, 11) min: 0.3869   max: 1.0000
#  errors_std shape: (11, 11) min: 0.0000   max: 0.0174
# errors_mean shape: (9, 11)  min: 0.3410   max: 1.0000
#  errors_std shape: (9, 11)  min: 0.0000   max: 0.0306
# States shape: (144, 1, 16, 11) = (time_step, leaf, state_variable)
# Target shape: (144,) = (time_step, target_variable)
# (11, 144)
